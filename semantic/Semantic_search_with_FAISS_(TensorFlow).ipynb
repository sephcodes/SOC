# %% [markdown]
# # Semantic search with FAISS (TensorFlow)

# %% [markdown]
# Install the Transformers, Datasets, and Evaluate libraries to run this notebook.

# %%
# !pip install datasets evaluate transformers[sentencepiece]
# !pip install faiss-gpu
# Out:
# Collecting datasets
#   Downloading datasets-2.15.0-py3-none-any.whl (521 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 6.5 MB/s eta 0:00:00
# Collecting evaluate
#   Downloading evaluate-0.4.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: transformers[sentencepiece] in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (10.0.1)
# Collecting pyarrow-hotfix (from datasets)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Collecting dill<0.3.8,>=0.3.0 (from datasets)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.1)
# Requirement already satisfied: huggingface-hub>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.19.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Collecting responses<0.19 (from evaluate)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (3.13.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.4.1)
# Collecting sentencepiece!=0.1.92,>=0.1.91 (from transformers[sentencepiece])
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 14.3 MB/s eta 0:00:00
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (3.20.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.18.0->datasets) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: sentencepiece, pyarrow-hotfix, dill, responses, multiprocess, datasets, evaluate
# Successfully installed datasets-2.15.0 dill-0.3.7 evaluate-0.4.1 multiprocess-0.70.15 pyarrow-hotfix-0.6 responses-0.18.0 sentencepiece-0.1.99
# Collecting faiss-gpu
#   Downloading faiss_gpu-1.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (85.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 MB 9.1 MB/s eta 0:00:00
# Installing collected packages: faiss-gpu
# Successfully installed faiss-gpu-1.7.2

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from datasets import Dataset

# %%
df = pd.read_csv(r'soc_202311261432.csv')
len(df)
# Out:
# 59121

# %%
X_train, X_test, y_train, y_test = train_test_split(df['JOB_DUTIES'], df['SOC_CODE'], test_size=0.2, random_state=42)

# %%
df_train = [{'text': text, 'label': label} for text, label in zip(X_train, y_train)]
df_test = [{'text': text, 'label': label} for text, label in zip(X_test, y_test)]

# %%
ds_train = Dataset.from_dict({key: [item[key] for item in df_train] for key in df_train[0]})
ds_test = Dataset.from_dict({key: [item[key] for item in df_test] for key in df_test[0]})

ds_train
# Out:
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 47296
# })

# %%
# ds_train_trim = ds_train.select(range(20000))
# ds_train_trim

# %%
# columns = issues_dataset.column_names
# columns_to_keep = ["title", "body", "html_url", "comments"]
# columns_to_remove = set(columns_to_keep).symmetric_difference(columns)
# issues_dataset = issues_dataset.remove_columns(columns_to_remove)
# issues_dataset

# %%
ds_train.set_format("pandas")
df = ds_train[:]

# %%
# df["comments"][0].tolist()
df['text'].tolist()
# Out:
# ['Tasks include: Operate vehicles and powered equipment, such as mowers, tractors, twin-axle vehicles, snow blowers, chainsaws, electric clippers, sod cutters, and pruning saws. Mow or edge lawns. Shovel snow and salt walks, driveways, or parking lots. Care for established lawns by mulching, aerating, weeding, grubbing, removing thatch, or trimming or edging around flower beds, walks, or walls.  Use hand tools, such as shovels, rakes, pruning saws, hedge or brush trimmers, or axes. Prune or trim trees, shrubs, or hedges. Gather and remove litter. Maintain or repair tools, equipment, or structures, such as building, greenhouses, fences, or benches, using hand or power tools. Mix and spray fertilizers, herbicides, or insecticides onto grass, shrubs, or trees.',
#  'Prepare construction site where concrete will be poured. Assist in pouring of concrete for finishers to complete. Use hand and power tools and carry various construction materials. Dig and level earth and gravel. Clean up construction site.',
#  'Perform a variety of food preparation duties other than cooking. Prepare a variety of foods, such as meats, vegetables, or desserts, according to customers. Place food trays over food warmers for immediate service, or store them in refrigerated storage cabinets.',
#  '***RFI Response***\n\xa0\n- Prep Station\n\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 \xa0 When they clock in they need to prep their station just like Soup, Sauce, Veg, Meat before the business open.\n\n- Cook\n\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 \xa0 Workers have to cook with a Chinese wok. We have our premade sauce in their station. We have a Chef assistant to prep all the ingredient and hand it to them, What they need to do is stir fry all veg, meat and sauce together and make sure that every ingredient is well done.\n\n- Fill ingredient\n\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 \xa0 After busy hours they need to clean up their station and fill all the sauce.\n\xa0\n-\xa0Prep Vegetable and Meat\n\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0They need to do it around afternoon after a 1 hour break. What they need to do is use Knife and Meat Slicer.\n\xa0\n- Cleaning\n\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 \xa0 Help to clean the kitchen just like Sweep, Mop, Wash station and wok. Keep all Meat and Veg in the refrigerator. (Cleaning job is not for one person but everybody need to help each other)\n\n\xa0***Original F.a.2***\n\nIn a day most of the job is on cook station  making an order.\nAfter rush time prep : Meat , Vegetable , Sauce , Curry.\nAfter business hours : Clean station , Check stock.\n\n\n',
#  'Greet, register and assign rooms to guests. Issue room keys. Make and confirm reservations. Collect payment. Answer questions, address complaints and report problems. Perform basic administrative duties associated with being a front desk clerk. Operating telephones in a polite and friendly manner following proper telephone etiquette, greeting members and guests, assisting with reservations and luggage, distributing information and schedules, and collecting and sorting the mail on a daily basis. May assist with breakfast preparation set up.  The Front Desk Clerk will also be responsible for making sure the rooms are properly cleaned and ready for check-in.',
#  'Mow lawns, edge, weed, plant, dig, water & feed plants, trim, prune, water lawns & flower beds, clean up, spread mulch, rake & blow leaves. May shovel snow. May operate & maintain the equipment & vehicles.',
#  'Prepares and install landscaping plans, and keeps grounds and landscape of private and business residences maintained. Prepare and grade terrain, applies fertilizers, seeds and sods lawn, and transplants shrubs and plants using manual power-operated equipment. Plants and cultivate lawns, using gardening implements and power-operated equipment.  Weeds and cleans grounds, using rakes, hoes, brooms, and other gardening tools. May dig trenches and install drain tiles.',
#  'Position offered is for an experienced landscape laborer with a minimum of two months experience in landscape labor who is able to work with and model company landscaping methods and procedures with up to 3 peers, mowing, weed trimming, pruning, digging, and raking or clean-up of leaves with blowers. Also, installation of plants, trees, and shrubs and trimming of plants trees and shrubs. Placing and tilling compost and sod. Installation of weed barriers. General landscape labor using landscape equipment for landscape installation and maintenance. Loading and unloading of materials and equipment. Lifting required up to 50 pounds. Work performed on local area jobsites with employer provided transportation to and from the jobsites from a centralized pickup location in the specified area of employment.',
#  'SPRING CLEANUPS,( REMOVAL OF LEAVES, STICKS USING BLOWERS AND RAKES,  AND THATCHING), FALL CLEANUPS, ( REMOVAL OF LEAVES), MOWING OF LAWNS, TRIMMING OF SHRUBS, WEEDING, MULCHING, SPREADING OF TOPSOIL, TREE & SHRUB PLANTINGS, IRRIGATION WORK INCLUDES INSTALLING IRRIGATION LINES USING SHOVELS, PICKS AND REPAIRING BROKEN SPRINKLER HEADS. OPERATING OF RIDE ON MOWERS, WEEDWACKERS, SHRUB TRIMMERS AND BLOWERS.',
#  'ESSENTIAL DUTIES & RESPONSIBILITIES FOR POSITION:\n1. Assist patients with personal care needs such as bathing, elimination needs, transferring, dressing/\nundressing, and ambulation together with any household task (e.g. making bed, changing\nlinens, laundry, light housekeeping, etc.) essential to patient’s health in accordance with the patient’s\nindividualized care plan.\n2. Plan/prepare nutritious meals and assist in feeding patients, as directed.\n3. Document services provided in accurate and timely manner in accordance with agency policy\nand personal care plan. Maintain patient confidentiality at all times.\n4. Measure and record patient’s temperature, pulse, respiration and blood pressure when requested\nand/or directed by the Nursing Supervisor and patient care plan.\n5. Report any changes in the patient’s condition or incidents to Nursing Department in a timely\nmanner.\n6. Performs tasks, skills as outlined on care plan competently.\n7. Notifies Nursing Department when clarification or education of a task is required.\n8. Uses EVV system to clock in and clock out for each visit accurately and timely. If EVV is not available,\nsubmits timecards/activity sheets in timely manner (i.e. weekly).\n9. Implements appropriate infection control practices.\n10. Demonstrates appropriate judgement skills to be able to make independent decisions in routine\npatient care matters.\n11. Assist patient with Passive Range of Motion (PROM) when requested and/or directed by the Nursing Supervisor/Physical Therapist or per plan of care',
#  'Arrange, organize, and execute activities, entertainment, and events throughout resort. Provides activity updates to all resort employees, guests, owners, and/or 3rd party vendors. Assist with communication to all resort channels. Ensure excellent customer service as it relates to activities. Performs other tasks as assigned.',
#  'Wash, clean, dry, and fold numerous hotel linen and laundry items.\nSort the laundry items according to material and color.\nArrange clothes in the laundry room as per the specifications.\nWrap the laundry items for pickup or delivery.\nUpdate the laundry list and record it on a daily basis.\n',
#  'DUTIES INCLUDE INSTALLATION OF TREES, SHRUBS, OR FLOWERS IN THE APPROPRIATE DESIGN PATTER. UNLOADING MATERIALS, DIGGING HOLES FOR ROOT SYSTEMS, PROPERLY COVERING THE HOLES AND SOMETIMES SOD LAYING, PLANTING GRASS SEED OR CONNECTING IRRIGATION. WORKERS MAY GATHER AND REMOVE LITTER, OPERATE POWERED EQUIPMENT AND DRIVE VEHICLES TO CUSTOMER LOCATIONS. DUTIES MAY INCLUDE SOD LAYING, MOWING, TRIMMING/PRUNING TREES, SHRUBS AND PLANTS, WATERING PLANTS & LAWNS, PLANT TRANSPLANTING, FERTILIZING, DIGGING, RAKING, SPRINKLER INSTALLATION, AND INSTALLATION OF MORTARLESS SEGMENTAL CONCRETE MASONRY WALL UNITS.',
#  'TAKE BEVERAGE ORDERS, PREPARE & SERVE MIXED DRINKS. TAKE FOOD ORDERS, RECOMMEND WINES & OTHER PRODUCTS. DISPLAY LIQUOR & SUPPLIES. KEEP BAR\nAREAS CLEAN & WORK UNDER STRICTLY ENFORCED STATE CODE.\n',
#  'Food and Beverage Supervisors will be responsible for overseeing an assigned outlet in the food and beverage operation in cooperation with the manager, including assisting with supervising, and training of staff.  Will be responsible for supervising and assisting in the setup of restaurants, restocking, and performing food preparation and food service duties when needed (including cooking, prepping, dishwashing, serving and hosting).  Will also be responsible for transporting staff and supplies to and from the work facility, overseeing cleaning of the assigned F&B area, opening and closing building, coordinating special events, directing weekly meetings, supervising and coordinating the activities of staff, and assisting with liquor control.  Will perform duties such as menu development, recipe building, creating prep sheets, ordering, inventory, performance reviews, and scheduling. May supervise up to twenty-five (25) Waitstaff, Bussers, Food Runners, Wait Assistants, Cashiers, Cooks, and Baristas.',
#  'As a construction laborer, the worker will perform tasks involving physical labor at construction sites. Worker may operate hand and power tools of all types: impacts, drills, surveying and measuring equipment, telehandlers, and a variety of other equipment and instruments. The construction laborer will unload materials, lay out materials, tin sheets and siding, trusses, ventilation equipment, and other components for light structure frames. The worker will build and erect light structure frames, which is comprised of light, handheld metal pieces, by hand and with basic hand tools such as impacts, drills, hammers, and pliers, water lines with catch cups, perches, doors and ramps. Lift tin sheets and siding to roof and walls, install doors, and caulk structure, and may assist other craft workers. Worker will install ventilation system including fans, stir fans, and tunnel doors by lifting them into the framed openings and fastening using impact and screws, hang heaters from ceiling using equipment to lift and chains to fasten to the ceiling. Worker will tend pumps, compressors, or generators to provide power for tools, machinery, or equipment. Lubricate, clean, or repair machinery, equipment, or tools. The construction laborer will signal equipment operators to facilitate alignment, movement, or adjustment of machinery, equipment, or materials. Worker will measure, mark, or record openings or distances to layout areas where construction work will be performed.',
#  'Prepare, season and cook soup, meat, vegetables, desserts, or other foodstuffs. Ensure food\nis stored and cooked at correct temperature by regulating temperature ovens, broilers, grills\nand roasters. Inspect and clean preparation areas, such as equipment and work surfaces, or\nserving to ensure safe and sanitary food handling practices. Ensure freshness of food and\ningredients by checking for quality, keeping track of old and new items, and rotating stock.',
#  'Prepare, season, and cook dishes such as soups, meats, vegetables, or desserts in restaurant. Report to work on time and in full uniform. Prepare food of consistent quality following recipe cards. Date all food containers and rotate as per SOP. Practice safety standards at all times. Cook orders as per chit from server. Handle any special food requests from guests. Start food items that are prepared ahead of time, making sure not to prepare over-estimated needs. Practice sanitation standards at all times. Ensure all perishables are kept at the proper temperatures. Properly portion all items on assigned station. Control food waste loss and usage per SOP. Assist in setting up plans and actions to correct any food cost problems. Check pars for shift use and determine necessary preparation, freezer pull and line set up. Note any out-of-stock items or possible shortages. Assist in keeping buffet stocked. Assist in prep work of vegetables and condiments as required for the next shift. Return all food items not used on next shift to designated storage areas, being sure to cover/date all perishables. Understand and apply 39-point checklist. Carry out reasonable requests by management and follow all rules in employee handbook.',
#  'Perform any combination of light cleaning duties to maintain a private household, where there is a long-term convalescent patient receiving care.\nDuties may include making beds, replacing bed pans,\nreplenishing linens, cleaning rooms and halls, and vacuuming.',
#  "Provide high-quality manicures and pedicures, which includes removing old nail polish from fingernails and toenails, cleaning nails, shaping the ends of nails, pushing back cuticles, and applying new polish based on clients' preferences. Apply artificial nails. Recommend various nail designs and nail art to clients. Evaluate the condition of clients’ nails and advising them on proper nail care and suitable nail care treatments. Sanitize all nail instruments and equipment before each use. Ensure that workstations are kept clean and orderly.\nEnsure that nail and massage supplies are adequately stocked. Provide quality hand and foot massages.",
#  'use hand/power tools to maintain lawns, dig holes using hand tools, will dig holes with a max depth/width of 1 ft to install sprinkler systems and/or plant, lay sod & plant. Installation of low voltage landscape lighting; check landscape lighting and décor to ensure in proper working order, replace inoperable lights or broken décor. Install mortarless segmental concrete masonry. May operate motorized vehicles. Involves loading and unloading tools and supplies and equipment weighing up to 50 lbs.  Involves working outdoors in all types of weather. Involves extensive standing, sitting or walking. Involves frequent stooping or bending. Involves repetitive movements.',
#  'Perform variety of attending duties at traveling carnival. Set up, tear-down, operate amusement rides, food concessions, game concessions.\n\nThe OFLC ETA requested detail on specific portions of these job duties.\n\nAmusement Rides set up & tear down: Mobile amusement rides are trailer mounted. A supervisor would position the trailer(s) at a specific location on the grounds, unhitch the power unit from the trailer, & move the power unit away from the ride. All of the pieces of the ride would travel on the same trailer(s) & be located proximate to their position when the ride is in operation. Work would be performed by individual workers as members of a team, with some tasks being performed individually & some collectively. Restraints holding pieces of the ride while in transit would be released. Ride platform (if any) would be lowered & leveled. Track or railing (if any) would be positioned & connected. Sweeps, supports, bars, pins would be positioned & connected. Cars, Seats, Bench or Carriage (method of conveyance for this particular ride) where patron would stand or sit while on the ride would be positioned & connected. Fencing, signage, ticket collection boxes & illumination would be positioned. Teardown would simply be these duties being handled in the reverse order & items being stored & secured for transit to the next location. May include moving/positioning, maintenance, repairs and refurbishment of equipment.\n\nFood Concessions set up & tear down: Mobile food concessions are typically mounted in a trailer. A supervisor would position the trailer(s) at a specific location on the grounds, unhitch the power unit from the trailer. The awnings covering the windows during transit would be raised & secured. Items such as trash cans, screens, tables that may be positioned outside of the trailer but carried inside of the trailer during transit would be manually moved from inside the trailer to outside. Trailer would be cleaned, sanitized & stocked with supplies for the event. Any counters, guidance railings, signage, decorations would be positioned outside of the trailer. Condiment dispensers, napkin dispensers & trash containers would be set up outside of the trailer. Typically the fair or event maintains the tables & chairs for patrons, but is some instances the worker may set up a limited number of chairs & tables for patron use. Teardown would\nsimply be these duties being handled in the reverse order & items being stored & secured for transit to the next location.\n\nGame Concessions: Mobile game concessions are typically mounted in a trailer. A supervisor would position the trailer(s) at a specific location on the grounds, unhitch the power unit from the trailer, & move the power unit away from the game concessions trailer. The awning that is closed during transit would be opened. Gaming items (air guns, water guns, darts, etc., as appropriate for the game) would be positioned. Plush toys and/or game appropriate prizes would be positioned / displayed. Signage, illumination, seating (if any), railings (if any), fencing (if any) would be positioned. Teardown would simply be these duties being handled in the reverse order & items\nbeing stored & secured for transit to the next location.\n\nTo clarify the portion of the job duties that includes operate mobile food concessions stand: On a carnival midway, when there is a mobile food concessions, a stand is limited to selling only one or two specific items, such as cotton candy, popcorn, turkey legs, roasted corn, or other specialty foods. The food is prepared in a production line, where an individual may only perform one task, such as measuring corn & oil into a popper. The next individual would salt & bag. The next individual would choose correct bag as per customer order & hand to teller. The next individual would have taken order, taken money, made change & then hands order to client.',
#  'drive a forklift/bobcat when needed, work at least 8 hrs a day, observe all safety policies and procedures, work can be fast paced; overtime will be required based on business needs, unload trucks, prepare items for shipping and load trailers, work in temperatures that vary from summer temperatures to lower degrees in the winter. Materials to be loaded: Plastic products, paper, cardboard.',
#  'ATTENDS TO THE OVERALL CARE OF\nTHOROUGHBRED RACEHORSES\nINCLUDING\nFEED, WATER,\nMAINTENANCE OF STALLS & TACK,\nCLEAN, BRUSH, TRIM OF HORSES,\nDISINFECT STALLS & BEDDING. WILL\nLIFT LEGS AND CLEAN HORSES FEET\nAND\nAPPLY LINIMENTS AND\nBANDAGES TO LEGS AS REQUIRED.\nWILL CARE FOR 1-5\nHORSES AT A\nTIME. SPLIT SHIFTS 5-11 AM AND 3-5\nPM. Days Off Rotates, workers will\nwork 40hrs a week unless they decide\nto work overtime',
#  'Greet guests and take drink and food orders. Attend to the needs of guests in the dining area. Deliver food from the kitchen to guests. Ensure the food orders are made correctly by kitchen staff and are presentable for guests. Follow health code standards in the handling and delivery of food. Perform shift duties like delivering racks of cups to the service station, rolling silverware, pre-bussing tables, wiping tables and removing debris. Assist with other food service tasks as\nneeded to ensure successful operations of busy restaurant.\n\n',
#  'JOB DUTIES INCLUDE: KENNEL MANAGEMENT, DOG RESCUE,  ANIMAL CARE AND REHABILITATION OF 500 DOGS RESCUED, VETTED AND RE-HOMED.',
#  'Prepare jobsite. Clean windows at residential and commercial properties using basic hand tools. Will wash windows at high elevations using extension ladders, aerial lift and rope descent. Adhere to all company safety rules and procedures. Maintain a clean and organized jobsite.',
#  'Laborers will be needed for turf care, pruning, fertilization, irrigation systems maintenance and repair, general clean up procedures around properties. Outdoor work, physical work.',
#  'Mowing, edging, blowing, fertilizing, planting of trees and shrubs, mulching, tree trimming.',
#  'Maintenance Engineers will be responsible for responding and attending to guest requests, communicating with guests to resolve maintenance issues, performing daily checks and preventative maintenance on tools and equipment, and troubleshooting and performing basic repairs on all types of equipment including plumbing and electrical equipment.',
#  'Flagstone work, dirt work, bed work, turf installation, sprinkler installation/repair, mowing, installation of plant materials, raking, outdoor landscape lighting and tree pruning. Lifting required up to 40 lbs.',
#  'Mowing, weedeating, bunker, raking, sodding, weed removal, mulching, tree pruning, assist with sprinkler systems.',
#  'WASH, PEEL, CUT, BROILS AND SAUTES VEGETABLES, FRUITS, AND MEATS SUCH AS POULTRY & SEAFOOD. CLEAN WORK AREAS. WASHES AND CLEANS POTS, PANS, SILVERWARE, PLATES BY HAND\nAND MACHINE. TAKES OUT GARBAGE TO DUMPSTERS.',
#  'Assist maintenance crew by checking PH balance, help install or replace pumps/equipment issues. Perform duties such as furnishing tools, materials and supply to workers; clean work area, machines and tools; holding materials or tools for other workers.',
#  'Diagnose and repair vehicles of all makes and and models.',
#  ' Landscape or maintain grounds of property using hand or power tools or equipment.  Workers typically perform a variety of tasks, which may include any combination of the following: sod laying, planting, seeding, watering, digging, and raking.  Assist with installation of mortarless segmental concrete masonry wall units and sprinkler systems.',
#  "Intent to try the following:\n• Confer with customers by telephone or in person to provide information about products or services, take or enter orders, cancel accounts, or obtain details of complaints. \n• Check to ensure that appropriate changes were made to resolve customers' problems. \n• Keep records of customer interactions or transactions, recording details of inquiries, complaints, or comments, as well as actions taken. \n• Resolve customers' service or billing complaints by performing activities such as exchanging merchandise, refunding money, or adjusting bills. \n• Complete contract forms, prepare change of address records, or issue service discontinuance orders, using computers",
#  '***RFI Response***\nJob Description:\nPrepare roads for resurfacing by utilizing a variety of hand and power tools, including blowers, weed eaters, push brooms and hand tools.\nThis includes but not limited to operation of a lute rake or squeegee to straighten asphalt joints and for hand working areas the paving machine is unable to reach.\nUnder supervision, spreads, rakes and finishes asphalt mixtures in connection with street maintenance and repair projects. \nSets up job site (including cones, barricades, high-rises and signs) in a safe manner\nSpreads and rakes asphaltic mixtures\nUses a squeegee to obtain a compact and smooth surface\nAssists in clean-up of job site after asphaltic repairs\nMay operate the screed on an asphalt paver\nMay be the groundman on an asphalt machine\nPerforms a variety of other tasks required in residential/main road/highway road preservation projects.\n\n***Original F.a.2***\nTransport materials to, from, and within the job site\n· Apply various products using a company truck\n· Maintain daily vehicle mileage logs\n· Perform minor servicing and maintenance of equipment; refer major problems to the Foreman\n· Must keep tuck in a clean and orderly condition\n· Follow directions of manager as to daily tasks and expectations for each specific project or job site\n· Perform other duties when necessary',
#  'Duties may include: Landscape and maintain property season tools or equipment. Tasks may include sod laying, mowing, trimming, planting, watering, fertilizing, digging, rake and blow leaves; seeding, mulching, hauling and spreading topsoil, installation of sprinklers and mortarless segmental concrete masonry wall units & other related Landscape Laborer activities as per SOC/OES 37-3011 (onetonline.org).\n\nPossible weekend/holiday work.',
#  'Kitchen Prep Chef / Line Cook / Kitchen Support is a multi tasked position. We work together as a team in our kitchen with duties such as:\nPrepping Items ie. cutting vegetables, making sauces, salad prep \nLine Cook ie. fryer foods, salads, wraps, possible grill cooking (training on site)\nKitchen Support ie. dishes, cleaning, stocking',
#  'Serve food, water, soft drinks & alcoholic beverages.\nPresent menus, take orders, relay order to kitchen. \nComplete side work, clear tables, carry dishes from dining room to kitchen, keep station areas clean.\nSupply clean linens, silverware, glassware, dishes in dining room.\nAssist with set-up, cleaning, opening/closing of restaurant/food and beverage area.\nMay be required to perform duties in an outdoor environment, at banquet events, or serve customers via golf cart.\nMay perform other reasonable job related duties as needed.\n',
#  'Take food orders and serve food and beverages to patrons in dining establishments. Set room for service, clear\nplates and glassware. Perform opening and closing side work which may include deep cleaning of the work\nareas.',
#  '***RFI Response***\n\nLandscape or maintain grounds of property using hand or power tools or equipment. Lay sod, mow, trim, plant, weeding, watering, dig holes with shovel, rake, blow leaves; spread grass seed, fertilizer and mulch; sprinkler installation/repair, installation of mortarless segmental concrete masonry wall units. Maintain equipment to ensure proper functioning. May drive company truck to transport crews, plants, materials and tools to/from or at worksites. Installing silt fence and laying slope matting.\n\n***Original F.a.2***\n\nUnder the direction of the foreman, the Specialist will conduct all the daily routine activities associated with Erosion Control Installation in a safe and efficient manner. Use shovels, picks, and sledge hammers to install silt fence. Operate straw blowers and hydroseeders. Assist in initial setup and cleanup of job sites. Install straw slope matting on slopes. Other duties as assigned.',
#  'Clean guest rooms, bath rooms and public areas of the establishment; vacuum, dust, sweep, collect trash, make beds, collect dirty laundry and restock linens load washing machines and iron and fold dried items.',
#  'Cleans hotel guestrooms according to service standards providing the highest level of quality and service for hotel guests. Anticipates guest needs, demonstrating sensitivity and responsiveness, ensuring complete satisfaction and repeat business. Duties include making beds, replenishing linens, cleaning rooms and halls, and vacuuming. Keep storage areas and carts well-stocked, clean, and tidy. Carry linens, towels, toilet items, and cleaning supplies, using wheeled carts. Clean rooms, hallways, lobbies, lounges, restrooms, corridors, elevators, stairways, locker rooms, and other work areas so that health standards are met.',
#  'Use hand-welding, flame-cutting, hand-soldering, or brazing equipment to weld or join metal components or to fill holes, indentations, or seams of fabricated metal products.',
#  'Maintain landscapes by performing tasks including but not limited to planting, pruning, mowing, and edging lawns and landscapes using mowers, trimmers, edgers, and related tools.  Pull weeds and clear leaves and debris using blowers. install lawns (sod) as per SEC/OES 37-3011.',
#  'Clean automobiles in dealer inventory by washing vehicle exterior\n\nWax car exterior to preserve paint\n\nVacuum and clean auto interior  \n\nRevitalize and Preserve exterior and interior with specialized processes, cleaners, and protectants provided by employer',
#  'Conduct training programs for Reining horses of all ages and levels of training, and compete them for top prizes and awards, from Levels 1 and 2 at the caliber of the National Reining Horse Association (NRHA) (international level), and/or other national/international competition associations and circuits.  Devise and start the training programs for horses especially geared toward NRHA competition Levels 1 and 2.  For each horse, confer with Head Trainer, Horse Owner and Rider(s) to assess horse’s capabilities and potential.  Plan short- and long-term competition goals for each young horse, spanning out three years.  Arrange travel of horses to competitions, and supporting logistics.  Implement nutrition and conditioning programs for all levels of competition horses, and supervise horse management and care pursuant to each horses’ unique needs.  Communicate with veterinarians/farriers to diagnose and treat horses’ ailments, and to maintain health.  Train and compete stallions and mares during breeding season schedules, and adapt to each horse’s changed temperament during the season.  Supervise support staff such as grooms, riders and assistant trainers.',
#  'Dormant & mid-season pruning; apply fertilizers; prepare lawns & flower beds for spring season; Mow, trim & edge lawns; water turf & flower beds, perform spring, fall & late season cleanups; weed beds; plant trees, shrubs, lawns, & flowers; spread mulch; install, repair sprinklers, installation of motarless segmental concrete masonry units',
#  'Responsible for applying various paint finishes to interior and exterior walls, ceilings, trims and doors using spray, rollers, or brush. Other duties include preparing and mixing paints to the desired colors and consistency, removing paints and preparing walls and surfaces prior to painting such as using fillers to repair cracks. Follows manager’s instructions in maintaining inventory and supplies .',
#  "Use power and hand tools to maintain lawns and flower beds. Install landscape material, i.e. flowers, grasses, shrubs. trees, retaining walls and other landscape features such as irrigation and decorative lighting as required to complete customer requests. Irrigation repair. Workers may be required to obtain a driver's license within 30 days and drive company vehicles between job sites. Easy seasonal administrative tasks may be required as team building\nexercises.",
#  'Serve food, water, soft drinks & alcoholic beverages. Present menus, take orders, relay order to kitchen.  Complete side work, clear tables, carry dishes from dining room to kitchen, keep station areas clean. Supply clean linens, silverware, glassware, dishes in dining room. Assist with set-up, cleaning, opening/closing of restaurant/food and beverage area. May be required to perform duties in an outdoor environment, at banquet events, or serve customers via golf cart. May perform other reasonable job related duties as needed.',
#  '***RFI Response***\n\nManually assemble and package product, including labeling, weighing, sealing, carton and loading pallets for shipment (includes label accuracy, package seal integrity, and counts per package and carton). Start-up, operate and shutdown basic technology manual, semi-automatic and automatic assembly/production machines and processes. Perform quality inspections in accordance with Panduit’s quality systems and procedures and complete all data entry functions. Engage in safety protocols in accordance with company safety guidelines and procedures. Waste elimination by preforming daily 5S activities. Specifically, the Production Operator assembles and packages plastic injection molding and extrusion products (our wiring duct and duct cover product line.) Panduit wire routing management and protection products offer premium solutions for unique applications needs. Our principal wiring duct and duct cover product at the Lockport facility where the H-2B employees will work is a cable routing system. The cable routing system is a collection of channels, fittings, and mounting brackets that can be assembled to create a structure that routes and protects fiber optic and high-performance copper data cabling. This type of system is an integral component of the overall cable management strategy to prevent physical damage that can result in a disruption of critical network connections. The Production Operators are assembling and packaging these channels, fittings, and mounting brackets.\n\n***Original F.a.2***\n\nManually assembles and packages product, including labeling, weighing, sealing, carton and loading pallets for shipment. Start up, operate, and shut down technology equipment and processes on manual and automatic equipment. Identify when troubleshooting is needed on equipment and processes and seek out others to assist. Execute across multiple basic technologies within the department.',
#  'Cut, trim, edge, water lawns & flower beds; clean up, weed removal in beds, plant, spread mulch, rake, blow leaves, fertilizing shrubs and flowers, digging, mowing, raking, pruning, core aerating, planting & transplanting, underground lawn sprinkler installation, landscape site preparation and development, debris removal, seeding & sodding of lawns. Must be able to lift 50 lbs.',
#  'Landscape or maintain grounds of property using hand or power tools or equipment. Workers typically perform a variety of tasks, which may include any combination of the following: sod laying, mowing, trimming, planting, watering, fertilizing, digging, and raking. May also perform minor repairs and maintenance procedures on equipment utilized in grounds-keeping and tree services through bracing, planting, pruning, removal, spraying, surgery, trimming.',
#  'Cook has to be able to prepare food in a timely manner. Must be able to work in a fast paced environment and handle pressure. Cook must also have a general understanding of how the food should be served and how it should be served. The employee should also be able to use a food slicer, processor, and blender for specific items we make. Knife skills are recommended, but not required. Must also be able to prepare raw meats such as poultry, beef, or pork. Sweeping and mopping skills when closing. Bilingual preferred (English and Spanish). Has to be able to read orders in English off KDS system to make the orders. Good Customer Service Skills are also required.',
#  'Perform variety of attending duties at traveling carnival.  Set up, tear-down, maintain/clean game concessions, inventory game parts and prizes.\nThe OFLC ETA requested detail on specific portions of these job duties.\nGame Concessions:  Mobile game concessions are typically mounted in a trailer.  A supervisor would position the trailer(s) at a specific location on the grounds, unhitch the power unit from the trailer, and move the power unit away from the game concessions trailer.  The awning that is closed during transit would be opened.  Gaming items (air guns, water guns, darts, etc., as appropriate for the fame) would be positioned.  Plush toys and/or game appropriate prizes would be positioned/displayed.  Signage, illumination, seating, railings, fencing would be positioned.  Teardown would simply be these duties being handled in the reverse order and items being stored and secured for transit to the next location.  Clean game concessions as needed and inventory parts and prizes at each location.',
#  'Landscape or maintain grounds of property using hand or power tools or equipment. Lay sod, mow, trim, plant, weeding, watering, dig holes with shovel, rake, blow leaves; spread seed, fertilizer and mulch; sprinkler installation/repair, installation of mortarless segmental concrete masonry wall units. May drive trucks or other vehicles to/from or at worksites. Maintain equipment to ensure proper functioning. Must be able to lift 50 lbs.',
#  'Ensure safety and maintain cleanliness of pool deck/health club area, equipment and guests. Assist guests with equipment and activities and respond to guests needs. Maintain facility supplies and ensure usage rules are adhered, maintain daily reports and logs. Maintain supply of pool towels for guests. Carry soiled towels to laundry, obtain clean pool towels from laundry and carry to pool deck, keep pool towels neatly folded and stacked for guest use. ',
#  'Cutting grass with many different types of machinery-weed eaters, push mowers, ride-on mowers. Drainage installation. Maintaining landscape beds- mulch, trimming, and fertilizer. Cutting/ trimming trees and brush.',
#  'Perform any combination of light cleaning duties in a resort hotel to maintain rooms in a clean and orderly manner. Duties include making beds, replenishing linens, cleaning rooms and halls, and vacuuming.  Cleaning, stocking, and maintaining hotel rooms as assigned which includes cleaning surfaces, mirrors, and bathrooms in the rooms and checking inventory of cleaning cart. ',
#  'The type of work in which construction workers will engage is non-agricultural. Projects include commercial, cooperative, and culvert projects. The workers will perform tasks involving physical labor at construction sites. The workers may also operate hand and power tools of all types, including but not limited to air hammers, earth tampers, cement mixers, small mechanical hoists, surveying and measuring equipment, and various other equipment and instruments. The workers may also clean and prepare sites, dig trenches, set braces to support the sides of excavations, install liners in culverts, chemical grouts of separated culverts, erect scaffolding, and clean up rubble, debris, and other waste materials. The workers may assist other craft workers and control traffic passing near, in, or around the work zones; workers may also clean or prepare construction sites to eliminate possible hazards. The workers may signal equipment operators to facilitate alignment, movement, or adjustment of machinery, equipment, or materials. The workers should read plans, instructions, or specifications to determine work activities, such as loading, unloading, or identifying materials, machinery, or tools. According to project plans or specifications, the workers may distribute building materials, machinery, and tools to the appropriate locations.',
#  'Drive trucks with capacities greater than 26,000 pounds Gross Vehicle Weight (GVW) , including tractor-trailer combinations, to transport and deliver products and other materials. Must be able to operate trailer, tractors semi-trailers.  Assist in loading and unloading in order to verify that the loading and unloading complies with the security and cargo protection conditions. Inspect loads to ensure that cargo is secure. Check vehicles to ensure that mechanical, safety, and emergency equipment is in good working order. Perform preventative maintenance to the truck such as adding oil, fuel, or radiator fluid and perform minor repairs.  Truck drivers must adequately and efficiently  identify the geographic location of the assigned pick up and delivery sites using  aids such as verbal direction, maps, GPS and other aids.  Comply with the requirements of the company to maintain documentation and reports following applicable state and federal regulations and company policy pertaining to functions of driver of Company vehicles. Check vehicles to ensure that mechanical, safety and emergency equipment is in good working order, follow appropriate safety procedures, and inspect loads to ensure that cargo is secure. Maintain logs of working hours following applicable state and federal regulationsmaneuver trucks into loading and unloading positions. Secure cargo for transport, using ropes, chains, blocks, binders, or covers.',
#  'Duties include but are not limited to constructing, erecting, installing, or repairing structures and fixtures made of wood and comparable materials, such as concrete forms; building frameworks, including partitions, joists, studding, and rafters; and wood stairways, window and door frames, and hardwood floors. May also install cabinets, siding, drywall, and batt or roll insulation. ',
#  'Construction laborers will perform manual labor, such as moving sandbags, debris and\nhundreds of thousands of square feet of liner material used for water containment and landfill\nlining systems. There landfill liners are designed and constructed to create a barrier between\nthe waste that is dumped in the landfill and the ground below it. When a new landfill is\nconstructed, referred to as a landfill cell, the geomembrane liner and other geosynthetic\nproducts are installed. There liner materials are tested to ensure that leachate is channeled\nproperly to a collection point rather than allowing leakage into the ground where it can become\na hazard to groundwater and the surrounding environment/communities.',
#  'Housekeepers: responsible for cleaning and maintaining all rooms, suites, and indoor common areas. Duties include vacuuming floors, dusting, replenishing linens and towels, disinfecting bathrooms, and washing windows. Housekeepers will need to lift and carry up to 50 pounds and go up and down stairs. No experience necessary; will train.',
#  'ASSIST WITH HOSPITALITY DUTIES AT A SMALL LODGE AND RESORT. CLEAN CABINS BY MAKING BEDS, DUSTING, VACUUMING, CLEANING KITCHENS AND BATHROOMS, AND DOING LAUNDRY. CHECK GUESTS IN AND OUT OF ROOMS, TAKE PAYMENT, ANSWER QUESTIONS, AND ATTEND TO THE LOBBY COUNTER. WORK IN THE LODGE RESTAURANT, SEATING GUESTS, TAKING ORDERS, BUSSING TABLES, WASHING DISHES, AND PERFORMING BASIC KITCHEN PREP WORK.     ',
#  'Raise vehicles, using hydraulic jacks .Remount wheels onto vehicles. Unbolt and remove wheels from vehicles, using lug wrenches or other hand or power tools. Place wheels on balancing machines to determine counterweights required to balance wheels. Identify tire size and ply and inflate tires accordingly.',
#  'Perform light housekeeping and cleaning such as clean hotel/resort guest rooms, condos, cottages, villas and public. This includes dusting, sweeping, moping & vacuuming, making beds & replenish linens. Clean bathroom & kitchen, emptying trash, cleaning hallways and public areas. May also clean kitchen, wash dishes, food preparation equipment, or utensils.',
#  'To lay and bind building materials, such as brick, structural tile, concrete block, glass block, and terra-cotta block.  To work with mortar and other substances to construct or repair walls, partitions, arches, and other structures.',
#  'Gather and remove litter; use hand tools such as shovels, rakes, pruning saws, saws, hedge\nor brush trimmers or\naxes; operate powered equipment such as mowers, chain-saws, electric clippers, sod cutters,\nor pruning saws;\nwater lawns, trees, or plants using portable sprinkler systems, hoses, or watering cans; prune\nor trim trees,\nshrubs, or hedges using shears, pruners, or chain saws',
#  "Workers will perform erosion control installation, fertilizing lawns, hydroseeding service, landscape installation, mowing, seeding, spraying, maintenance of plants and shrubs, pruning removal trimming  and sodding.  Job site types include residential, commercial, highway and Forestry.  Additional tasks may include facility/equipment maintenance & inventory. Involves bending, stooping, lifting and stretching on a frequent basis. Must be able to lift 50 lbs often, work in extreme weather.  Must undergo drug testing and background check. The company's government contracts make this requirement a necessity. Optional housing at cost comparable to local market, if available. Possibility of performance based raise, bonus, overtime and Saturdays. 1 hr non paid lunch. Transportation provided to worksites from central location in Olive Branch, MS. Must pass employer paid post hire drug test. Must pass employer paid post hire background check.",
#  'Landscape or maintain grounds of property using hand or power tools or equipment. Workers typically perform a variety of tasks, which may include any combination of the following: sod laying, pruning, planting, watering, fertilizing, digging, raking, and installation of mortarless concrete masonry/stone landscape units.  Must exercise independent judgment; may be asked to demonstrate tasks to other employees but position does not include supervision of other workers.',
#  'RECEIVES & DISBURSES MONEY, USES SCANNERS & CASH REGISTERS. PROCESSES CREDIT CARDS\n',
#  " Perform manual labor to landscape or maintain grounds of property using hand or power tools or equipment. Lay sod, mow, trim, plant, water, dig, rake, haul and shovel. Operate powered equipment such as mowers, tractors, twin-axle vehicles, snow blowers, chainsaws, electric clippers, sod cutters, and pruning saws. Use hand tools such as shovels, rakes, pruning saws, saws, hedge and brush trimmers, and axes. Mow and edge/trim lawns, using power mowers and edgers. Shovel snow from walks, driveways, and parking lots and spread salt in those areas. Care to established lawns by mulching, aerating, weeding, grubbing and removing thatch, and trimming and edging around flower beds, walks, and walls. Water lawns, trees, and plants using portable sprinkler systems, hoses, or watering cans.  Haul or spread topsoil and spread straw over seeded soil to hold soil in place. Trim and pick flowers and clean flower beds. Decorate gardens with stone and plants. Rake, mulch and compost leaves. Prune and trim trees, shrubs, and hedges using shears, pruners, or chainsaws. Attach wires from planted trees to support stakes. Plant seeds, bulbs, foliage, flowering plants, grass, ground covers, trees, and shrubs and apply mulch for protection using gardening tools. Gather and remove litter. Drug free workplace. Drug testing may be conducted throughout the employment period at no cost to the worker. Workers who have a valid driver's license may drive vehicles to transport workers and may be offered additional hours.",
#  'Cares for and cleans horses; exercises and inspects them according to instructions.',
#  'Sod laying, planting, mowing, trimming, digging, raking, pruning, and mulching. Lifting requried up to 50lbs.',
#  'Keep buildings and grounds in clean and orderly condition. Perform heavy cleaning duties, such as cleaning floors, shampooing rugs, washing walls and glass, and removing rubbish. Duties may include tending furnace and boiler, performing routine maintenance activities, notifying management of need for repairs, and cleaning snow or debris from sidewalk.',
#  'SERVE CUSTOMERS MEALS. CLEAN, ORGANIZE EATING SERVICE AND KITCHEN AREAS. PREPARE SANDWICHES, SALADS. DELIVER FOOD TO GUESTS. KEEP REFRIDERATORS STOCKED WITH SUPPLIES.',
#  'Mow, trim, edge; clean up, weed, plant, spread mulch; rake, blow leaves and prune. May operate vehicles.',
#  "As a horse groom/stable attendant, the worker will assist with the daily care of horse's and preparation of horses for training as well as participation in horse shows. The workers will travel to competitions in order to help prepare horses for show rings. They have the responsibility to feed and water horses, clean, tack, bath, brush, and clip horses, apply horse boots and prepare horses to be saddled for shows. They will clean horse's feet, apply/ remove leg wraps/boots and saddle for training. Bath/cool down horse after training/showing. Assist veterinarian while performing physical examinations, by keeping the horse calm and under control. They will also assist the farriers as they inspect, remove, apply, adjust, and work with horse's hoof and shoes by keeping the horse calm and under control. Clean/re-bed stalls. Hose down horse with cold/warm water. Wrap horse in brace or poultice bandages as necessary.",
#  'Remove and clean up snow using snow blowers and standard commercial snow shovels, leaf removal, load/unload materials. Lift up to 50 lbs.',
#  'serve food and beverages\nclear, properly clean and set tables between uses\ncollect payment from customers in a timely manner\nHelp food preparation staff when necessary.',
# ...
#  'WORK AS A RETAIL COUNTER CLERK AT A COMMERCIAL GARDEN CENTER. RECEIVE PLANTS AND DISPLAY THEM. ANSWER CUSTOMER QUESTIONS. OPERATE THE COUNTER AND CASH REGISTER. TAKE PAYMENT. ASSIST GUESTS WITH LOADING THEIR PURCHASES. CLEAN AND MAINTAIN ALL GARDEN CENTER FACILITIES.',
#  'Landscape or maintain grounds of property using hand or power tools or equipment.  Workers must be able to perform a variety of tasks without close supervision, which may include any combination of the following:   sod laying, mowing, trimming, planting, watering, fertilizing, digging, raking, and mulching. Must exercise independent judgment; may be asked to demonstrate tasks to other employees but position does not include supervision of other workers.',
#  'LANDSCAPE OR MAINTAIN GROUNDS OF PROPERTY USING HAND OR POWER TOOLS OR EQUIPMENT. SOD LAYING, MOWING, TRIMMING, PLANTING, WATERING, FERTILIZING, DIGGING, RAKING, SPRINKLER SYSTEM INSTALLATION, AND INSTALLATION OF MORTARLESS SEGMENTAL CONCRETE MASONRY WALL UNITS.',
#  'Take orders, inform kitchen of items ordered, serve or deliver food and beverages to resort guests, present check to guest, clear table or remove tray from guestroom. Assist with opening and closing of restaurant or food and beverage area. Set-up, clean, tear down workstation, prepare side work. Follow required safe cleaning and sanitizing procedures.',
#  'Duties may include: Landscape and maintain properties using tools or equipment.  Tasks may include sod laying, mowing, trimming, planting, watering, fertilizing, digging, rake and blow leaves; seeding, mulching, hauling and spreading topsoil, installation of sprinklers and mortarless segmental concrete masonry wall units & other related Landscape Laborer activities as per SOC/OES 37-3011 (onetonline.org).\n\nPossible weekend/holiday work.',
#  'Tasks:  Landscape or maintain grounds of property using hand or power tools or equipment. Tasks may include: sod laying, mowing, trimming, planting, watering, fertilizing, digging, raking, sprinkler installation, and installation of mortarless segmental concrete masonry wall units.',
#  'Duties may include: Landscape & maintain properties using tools or equipment. Tasks may include sod laying, mowing, trimming, planting, watering, fertilizing, digging, rake & blow leaves; seeding, mulching, hauling & spreading topsoil, installation of mortarless segmental concrete masonry wall units & other related Landscape Laborer activities as per SOC/OES 37-3011 (onetonline.org).\n\nPossible weekend/holiday work.',
#  'ATTENDS TO THE OVERALL CARE OF THOROUGHBRED RACEHORSES INCLUDING FEED, WATER, MAINTENANCE OF STALLS & TACK, CLEAN, BRUSH, TRIM OF HORSES, DISINFECT STALLS & BEDDING. WILL LIFT LEGS AND CLEAN HORSES FEET AND APPLY LINIMENTS AND BANDAGES TO LEGS AS REQUIRED. WILL CARE FOR 1-5 HORSES AT A TIME. SPLIT SHIFTS 5-11 AM AND 3-5 PM. Days Off Rotate.',
#  'ASSIST IN GREENHOUSE FLOWER PROPOGATION. HELP UNLOAD TRUCKS.   CLEANING DEBRIS FROM WALKWAYS AND WORK AREAS. ASSIST WITH FURNITURE DELIVERY. MAY DRIVE COMPANY VEHICLES. MUST BE ABLE TO LIFT 50 POUNDS. WILL TRAIN.  MUST HAVE VALID DRIVING LICENSE.',
#  'Duties may include: Manual duties outdoors for reforestation: maintain, develop woodlands, hand plant tree seedlings without J or U root; maintain surrounding vegetation by thinning, pruning, clearing, and piling debris. Fight forest fires or perform prescribed burning tasks under the direction/supervision of fire suppression officers or forestry technicians via clearing/disposing of brush, piling, and digging line/constructing fire breaks & other related Forestry Worker activities as per SOC/OES 45-4011 (onetonline.org).\n\nPossible weekend/holiday work.',
#  'Cutting, trimming of shrubs and plants, mowing, edging of lawns and flowerbeds, watering/irrigation, raking/ blowing of leaves, cleaning of debris, planting plants and flowers and other related duties of landscaping.  Work is supervised.',
#  'Housekeepers will be responsible for cleaning and maintaining all rooms, suites, and indoor common areas at The Pitcher Inn at Warren and The Warren Store’s property, which includes vacuuming floors, dusting, replenishing linens and towels, disinfecting bathrooms, washing and ironing linens, carrying firewood, stocking housekeeping supplies, keeping entrances clean and clear, removing trash, and washing windows.',
#  'Non supervisor position. \nBagging via automated system.\n Pick up bag, place into system, apply label.  Automated system picks up bag and palletizes. Move pallet to wrapping area via forklift. Push button for wrapping of pallet.  Move pallet to storage area.\nClean up at end of day.',
#  'Maintain grounds of property using hand or power tools or equipment. Workers typically perform a variety of tasks, which may include any combination of the following: trimming, raking, clean up of limbs and leaves, shredding of larger tree branches, set up of equipment.',
#  'Erect and repair fences and fence gates, using hand and power tools.  Workers typically perform a variety of tasks, which may include any combination of the following: load/unload equipment/supplies, carry/hold materials, dig holes, remove existing fencing, install new fencing. Cleanup debris as part of installation or service process; clean and maintain equipment/tools when not in use and ensure proper storage at end of day.',
#  'Serve food, water, soft drinks & alcoholic beverages.\nPresent menus, take orders, relay order to kitchen. \nComplete side work, clear tables, carry dishes from dining room to kitchen, keep station areas clean.\nSupply clean linens, silverware, glassware, dishes in dining room.\nAssist with set-up, cleaning, opening/closing of restaurant/food and beverage area.\nMay be required to perform duties in an outdoor environment or at banquet events.\nMay perform other reasonable job related duties as needed.',
#  'Mowing, raking, leaf blowing ,weeding, mulching, edging, sod laying, planting, trimming, digging, loading and unloading materials. Lifting required up to 35 Lbs.',
#  'Provide assistance during nine months of peak construction projects of the company primarily involving off-season baseball and softball fields. Perform tasks involving physical labor at construction sites. Operate hand and power tools of all types: air hammers, earth tampers, cement mixers, small mechanical hoists, surveying and measuring equipment, and a variety of other equipment and instruments. Prepare sites, dig trenches, set braces to support the sides of excavations, erect scaffolding, and clean up rubble, debris, and other waste materials. Signal equipment operators to facilitate alignment, movement, or adjustment of machinery, equipment, or materials. Load, unload, or identify building materials, machinery, or tools, distributing them to the appropriate locations, according to project plans or specifications.',
#  'Duties may include: Landscape or maintain properties using tools or equipment. Tasks may include mowing, trimming, planting, watering, fertilizing, digging, raking, shoveling, & pulling weeds by hand, spread mulch, trim shrubs & plants. Maintain work area includes removal of trash, debris, or plants, etc. Minor maintenance on lawn equipment when time allows & other related Landscape Laborer activities as per SOC/OES 37-3011 (onetonline.org).\n\nPossible weekend/holiday work.',
#  'Use hand tools, such as shovels, rakes, pruning saws, saws, hedge or brush trimmers, or axes. Operate vehicles or powered equipment, such as mowers, weed-eater blower, tractors, twin-axle vehicles, chain-saws, electric clippers, sod cutters, or pruning saws. Water lawns, trees, or plants, using portable sprinkler systems, hoses, or watering cans. Prune or trim trees, shrubs, or hedges, using shears, pruners, or chain saws. Cutting grass, weed eating, edging, blowing grass clippings off concrete, weed pulling, planting shrubs/trees/flowers, building new beds, mulching, shrub trimming, use wheel barrel to move materials.',
#  'Housekeepers will be responsible for cleaning and maintaining all rooms, suites, and indoor common areas at The Grand Hotel’s property, which includes vacuuming floors, dusting, replenishing linens and towels, disinfecting bathrooms, and washing windows.',
#  'Doing landscaping maintenance. Seasonal services include mulching, aerating, weeding, grubbing, removing thatch, and trimming/edging around flower beds, walks, and walls. Mow lawns. Plant seeds, bulbs, foliage, flowering plants, grass, ground covers, trees, and shrubs, and apply mulch for protection, using gardening tools.',
#  "Delivering freight over long distances across the country's road networks. Planning routes efficiently and delivering freight on time. Performing prescribed truck inspections before departure to ensure good running order. Documenting the freight's condition before departure and inventorizing loads. Securing the freight in place before departure and monitoring its safe distribution throughout the trip. Supervising the loading and unloading of freight, and obtaining the client's signature on delivery. Performing service checks on tire pressure, oil, and fluid levels, as well as minor repairs, when required. Logging hours and distances driven, rest stop durations, as well as all fuel, repair, and toll expenses. Communicating any delays due to road conditions, accidents, or breakdowns to dispatchers. Complying with federal and state trucking rules and regulations, including mandatory rest periods and weight restrictions.",
#  'SPRING CLEANUPS,( REMOVAL OF LEAVES, STICKS AND THATCHING), FALL CLEANUPS,( REMOVAL OF LEAVES), MOWING OF LAWNS, TRIMMING OF SHRUBS, WEEDING, MULCHING, SPREADING OF TOPSOIL, TREE & SHRUB PLANTINGS, IRRIGATION WORK. OPERATING OF RIDE ON MOWERS, WEEDWACKERS, SHRUB TRIMMERS AND BLOWERS.',
#  'Landscape or maintain grounds of property using hand or power tools or equipment. Employees will install edging, soil, mulch, rock, plants, trees, drain tile systems, and sod. Employees will also place pavers, stone, and retaining walls. Installation includes excavation of site to create graded pad for drainage, spreading base material with hand tools and moving and position pavers or retain wall blocks. Employees will be limited to placing pavers and stone by hand and with hand tools.',
#  'Landscape or maintain grounds of property using hand or power tools or equipment. Mowing, trimming, planting, digging, raking, leaf blowing, pruning, mulching, install annual flowers, edging, cleanup, and sprinkler installation. Must be able to bend, stoop and stand on feet for long periods of time and physically able to meet and perform all job specifications. Must be able to lift and carry up to 50 lbs.',
#  'Diesel Truck mechanic For a private carting company with experience on Hydraulic System\n-Perform diagnostic tests for routine maintenance procedures.\n-Order parts and repair Trucks.\n-Repair components that malfunction.\n-Reconditioning engines.\n-Steering system adjustments.\n-Break systems.\n-Adjustments on clutches.\n-Hydraulic System.\n-Replacing worn parts.\n-Changing motor oil and Greasing Equipment & anything that is necessary or requested.',
#  'dig holes to plant seedling trees without J or U root, carefully secure seedling with soil,\nmaintain seedling growth by spray, hand prune, maintain surrounding vegetation, pile/remove\ndebris, identify disease/undesirable trees and remove them, thin and space trees with the use\nof power saws and hand saws. Gather/Package forest products.\nMaintain tallies of trees examined. Job duties require moving your entire body, such as\nclimbing, lifting, balancing, walking, stooping and handling of materials. Extensive walking\nthrough rough terrain.',
#  'Duties may include: Duties may include: Maintain and develop woodlands; include hand plant tree seedlings w/o J or U root. Maintain surrounding vegetation: Identify diseased or undesirable trees and remove them, using chain saws. UNDER THE DIRECTION OF FIRE SUPPRESSION OFFICERS OR FORESTRY TECHNICIANS: fight forest fires or perform prescribed burning tasks, fire protection, and suppression via clearing/disposing of brush, piling, and digging line/constructing fire breaks & other related Forestry Worker activities as per SOC/OES 45-4011 (onetonline.org).\n\nPossible weekend/holiday work.',
#  'Cook and prepare a variety of food according to production guidelines and standardized recipes. Safely utilize a variety of utensils and equipment to prepare and cook all types of foods. Arrange, garnish, and portion food according to established guidelines. Properly store food by adhering to food safety policies and procedures. Cleans and sanitizes work areas, equipment, and utensils.',
#  'Guide guests down class II and III whitewater. \nProvide a safety orientation and paddling instruction.\nEntertain guests with history and environmental interpretation. \nLoad and unload rafts. \nClean wetsuits, PFDs and helmets at the end of each trip. ',
#  'Seeking for skilled and strong experienced Bus and Truck Mechanics and Diesel Engine Specialists to diagnose, adjust, repair, or overhaul buses and trucks, or maintain and repair any type of diesel engines. Includes mechanics working primarily with heavy and tractor trailer trucks and marine diesel engines.\n\nOn the job training will be provided. No education required. 5 years experience required.\nTransportation provided to and from area job sites from a central Midland County area pick up location',
#  'Responsibilities:\n•\tProfessional Team Communication\n•\tCompletes Daily Tasks and Assigned Project Work\n•\tKitchen Set Up and Breakdown\n•\tDish Area Cleanliness and Trash Removal\n•\tReceiving and Rotation of Food Supplies\n•\tAdheres to Uniform and Grooming Standards\n•\tContinuous Development of Hooters Kitchen Knowledge\n•\tPractices Proper Food Safety & Sanitation Standards\n•\tEnsures Food Quality Standards\n•\tEnsures Food Presentation is Visually Appealing & Picture   Perfect\n•\tFollows Hooters Recipes and Operating Procedures & Systems\n•\tAdheres to Hooters Kitchen Uniform and Hygiene Standards\n•\tPractices Proper Food Safety & Sanitation Standards\n•\tEnsures Food Quality Standards\n•\tEnsures Food Presentation is Visually Appealing & Picture   Perfect\n•\tFollows Hooters Recipes and Operating Procedures & Systems\n•\tAdheres to Hooters Kitchen Uniform and Hygiene Standards',
#  'Separate blocks of rough dimension stone from quarry mass using jackhammer and wedges.',
#  "To drive passenger buses transporting customers to various locations. Communicates with passengers regarding route changes, arrival and departure updates, boarding instructions, emergencies, etc. Operates radios to communicate with terminals. Assists disabled passengers as needed and assists passengers with luggage. 6 months exp.\n\nSpanish preferred. Must have or be able to obtain a Class A or Class B license with passenger endorsement or the foreign equivalent. Pre-employment physical exam, drug testing, and background check (criminal record) is required at the company's expense. ",
#  'Duties may include: Inspect trees to determine if they have diseases or pest problems. Climb trees using climbing hooks, belts or ladders to gain access to work areas. Trim and cut away dead or excess branches from trees. Clear branches around power lines using climbing equipment, buckets of extended truck booms, chainsaws, handsaws, shears, and clippers. Spray and treat diseased or unhealthy trees, including mixing chemicals and calibrating spray equipment. Operate loaders, stump chippers, brush chippers, tractors, trucks, and other equipment and tools. Clear sites, streets, and grounds of debris such as tree stumps, fallen trees and limbs. Operate shredding and chipping equipment and feed limbs and brush into the machines & other related Tree Trimmer activities as per SOC/OES 37-3013 (onetonline.org).\n\nPossible weekend/holiday work.',
#  'Cares for and cleans horses; exercises and inspects them according to instructions',
#  ...]

# %%
text_df = df.explode("text", ignore_index=True)
text_df.head()
# Out:
#                                                 text       label
# 0  Tasks include: Operate vehicles and powered eq...  37-3011.00
# 1  Prepare construction site where concrete will ...  47-2061.00
# 2  Perform a variety of food preparation duties o...  35-2021.00
# 3  ***RFI Response***\n \n- Prep Station\n       ...  35-2014.00
# 4  Greet, register and assign rooms to guests. Is...  43-4081.00

# %%
text_dataset = Dataset.from_pandas(text_df)
text_dataset
# Out:
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 47296
# })

# %%
text_dataset = text_dataset.map(
    lambda x: {"text_length": len(x["text"].split())}
)
# Out:
# Map:   0%|          | 0/47296 [00:00<?, ? examples/s]

# %%
text_dataset = text_dataset.filter(lambda x: x["text_length"] > 5)
text_dataset
# Out:
# Filter:   0%|          | 0/47296 [00:00<?, ? examples/s]
# Dataset({
#     features: ['text', 'label', 'text_length'],
#     num_rows: 47248
# })

# %%
# def concatenate_text(examples):
#     return {
#         "text": examples["title"]
#         + " \n "
#         + examples["body"]
#         + " \n "
#         + examples["comments"]
#     }


# comments_dataset = comments_dataset.map(concatenate_text)

# %%
from transformers import AutoTokenizer, TFAutoModel

model_ckpt = "sentence-transformers/multi-qa-mpnet-base-dot-v1"
tokenizer = AutoTokenizer.from_pretrained(model_ckpt)
model = TFAutoModel.from_pretrained(model_ckpt, from_pt=True)
# Out:
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFMPNetModel: ['embeddings.position_ids']
# - This IS expected if you are initializing TFMPNetModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFMPNetModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFMPNetModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFMPNetModel for predictions without further training.

# %%
def cls_pooling(model_output):
    return model_output.last_hidden_state[:, 0]

# %%
def get_embeddings(text_list):
    encoded_input = tokenizer(
        text_list, padding=True, truncation=True, return_tensors="tf"
    )
    encoded_input = {k: v for k, v in encoded_input.items()}
    model_output = model(**encoded_input)
    return cls_pooling(model_output)

# %%
embedding = get_embeddings(text_dataset["text"][0])
embedding.shape
# Out:
# TensorShape([1, 768])

# %%
embeddings_dataset = text_dataset.map(
    lambda x: {"embeddings": get_embeddings(x["text"]).numpy()[0]}
)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# Map:   0%|          | 0/47248 [00:00<?, ? examples/s]

# %%
embeddings_dataset
# Out:
# Dataset({
#     features: ['text', 'label', 'text_length', 'embeddings'],
#     num_rows: 47248
# })

# %%
import joblib

# Save the dataset along with the Faiss index
joblib.dump(embeddings_dataset, "embeddings_dataset.joblib")
# Out:
# ['embeddings_dataset.joblib']

# %%
# embeddings_dataset.add_faiss_index(column="embeddings")

# %%
# !pip install supabase
# Out:
# Collecting supabase
#   Downloading supabase-2.3.0-py3-none-any.whl (15 kB)
# Collecting gotrue<3.0,>=1.3 (from supabase)
#   Downloading gotrue-2.1.0-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 kB 1.9 MB/s eta 0:00:00
# Collecting httpx<0.25.0,>=0.24.0 (from supabase)
#   Downloading httpx-0.24.1-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 10.0 MB/s eta 0:00:00
# Collecting postgrest<0.14.0,>=0.10.8 (from supabase)
#   Downloading postgrest-0.13.0-py3-none-any.whl (19 kB)
# Collecting realtime<2.0.0,>=1.0.0 (from supabase)
#   Downloading realtime-1.0.2-py3-none-any.whl (8.9 kB)
# Collecting storage3<0.8.0,>=0.5.3 (from supabase)
#   Downloading storage3-0.7.0-py3-none-any.whl (15 kB)
# Collecting supafunc<0.4.0,>=0.3.1 (from supabase)
#   Downloading supafunc-0.3.1-py3-none-any.whl (6.1 kB)
# Requirement already satisfied: pydantic<3,>=1.10 in /usr/local/lib/python3.10/dist-packages (from gotrue<3.0,>=1.3->supabase) (1.10.13)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<0.25.0,>=0.24.0->supabase) (2023.11.17)
# Collecting httpcore<0.18.0,>=0.15.0 (from httpx<0.25.0,>=0.24.0->supabase)
#   Downloading httpcore-0.17.3-py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 kB 10.1 MB/s eta 0:00:00
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx<0.25.0,>=0.24.0->supabase) (3.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<0.25.0,>=0.24.0->supabase) (1.3.0)
# Collecting deprecation<3.0.0,>=2.1.0 (from postgrest<0.14.0,>=0.10.8->supabase)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Collecting strenum<0.5.0,>=0.4.9 (from postgrest<0.14.0,>=0.10.8->supabase)
#   Downloading StrEnum-0.4.15-py3-none-any.whl (8.9 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from realtime<2.0.0,>=1.0.0->supabase) (2.8.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from realtime<2.0.0,>=1.0.0->supabase) (4.5.0)
# Collecting websockets<12.0,>=11.0 (from realtime<2.0.0,>=1.0.0->supabase)
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 16.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from deprecation<3.0.0,>=2.1.0->postgrest<0.14.0,>=0.10.8->supabase) (23.2)
# Collecting h11<0.15,>=0.13 (from httpcore<0.18.0,>=0.15.0->httpx<0.25.0,>=0.24.0->supabase)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from httpcore<0.18.0,>=0.15.0->httpx<0.25.0,>=0.24.0->supabase) (3.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.8.1->realtime<2.0.0,>=1.0.0->supabase) (1.16.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->httpcore<0.18.0,>=0.15.0->httpx<0.25.0,>=0.24.0->supabase) (1.2.0)
# Installing collected packages: strenum, websockets, h11, deprecation, realtime, httpcore, httpx, supafunc, storage3, postgrest, gotrue, supabase
# Successfully installed deprecation-2.1.0 gotrue-2.1.0 h11-0.14.0 httpcore-0.17.3 httpx-0.24.1 postgrest-0.13.0 realtime-1.0.2 storage3-0.7.0 strenum-0.4.15 supabase-2.3.0 supafunc-0.3.1 websockets-11.0.3

# %%
import os
from supabase import create_client, Client

os.environ["SUPABASE_URL"] = os.environ['SUPABASE_URL']
os.environ["SUPABASE_KEY"] = os.environ['SUPABASE_KEY']

url: str = os.environ.get("SUPABASE_URL")
key: str = os.environ.get("SUPABASE_KEY")
supabase: Client = create_client(url, key)

# %%
# !pip install vecs
# Out:
# Collecting vecs
#   Downloading vecs-0.4.2.tar.gz (21 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pgvector==0.1.* (from vecs)
#   Downloading pgvector-0.1.8-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied: sqlalchemy==2.* in /usr/local/lib/python3.10/dist-packages (from vecs) (2.0.23)
# Collecting psycopg2-binary==2.9.* (from vecs)
#   Downloading psycopg2_binary-2.9.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 23.3 MB/s eta 0:00:00
# Collecting flupy==1.* (from vecs)
#   Downloading flupy-1.2.0.tar.gz (12 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting deprecated==1.2.* (from vecs)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated==1.2.*->vecs) (1.14.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from flupy==1.*->vecs) (4.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pgvector==0.1.*->vecs) (1.23.5)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy==2.*->vecs) (3.0.2)
# Building wheels for collected packages: vecs, flupy
#   Building wheel for vecs (pyproject.toml) ... done
#   Created wheel for vecs: filename=vecs-0.4.2-py3-none-any.whl size=23473 sha256=fcbad2ab0a865e905dd6285839397f4120eccbd0177b4fecc2e705a6fac48641
#   Stored in directory: /root/.cache/pip/wheels/59/a9/d0/719425485ea3d64018495710560fdf420261a456170a56173c
#   Building wheel for flupy (pyproject.toml) ... done
#   Created wheel for flupy: filename=flupy-1.2.0-py3-none-any.whl size=11020 sha256=43c7dde0ecf53f2b516f4aba5a6076653556406aeadbf230a6f86cec6ac74edf
#   Stored in directory: /root/.cache/pip/wheels/3a/09/29/1d3dfb180f729ca647ff2e1177f344c54ec35eb326238a3346
# Successfully built vecs flupy
# Installing collected packages: psycopg2-binary, pgvector, flupy, deprecated, vecs
# Successfully installed deprecated-1.2.14 flupy-1.2.0 pgvector-0.1.8 psycopg2-binary-2.9.9 vecs-0.4.2

# %%
import vecs

DB_CONNECTION = os.environ['SUPABASE_POSTGRE']

# create vector store client
vx = vecs.create_client(DB_CONNECTION)

# %%
data, count = supabase.table('TEST').insert([{col: row[col] for col in embeddings_dataset.column_names} for row in embeddings_dataset]).execute()

# %%
supabase.table('TEST').select("*").execute()

# %%
# question = "Perform variety of attending duties at traveling carnival.  Set up, tear-down, operate amusement food concessions.\nThe OFLC ETA requested detail on specific portions of these job duties.  \nFood Concessions set up & tear down:  Mobile food concessions are typically mounted in a trailer.  A supervisor would position the trailer(s) at a specific location on the grounds, unhitch the power unit from the trailer.  The awnings covering the windows during transit would be raised & secured.  Items such as trash cans, screens, tables that may be positioned outside of the trailer but carried inside of the trailer during transit would be manually moved from inside the trailer to outside.  Trailer would be cleaned, sanitized & stocked with supplies for the event.  Any counters, guidance railings, signage, decorations would be positioned outside of the trailer. Condiment dispensers, napkin dispensers & trash containers would be set up outside of the trailer. Typically the fair or event maintains the tables & chairs for patrons, but is some instances the worker may set up a limited number of chairs & tables for patron use.  Teardown would simply be these duties being handled in the reverse order & items being stored & secured for transit to the next location.\nTo clarify the portion of the job duties that includes operate mobile food concessions stand:   On a carnival midway, when there is a mobile food concessions, a stand is limited to selling only one or two specific items, such as cotton candy, popcorn, turkey legs, roasted corn, or other specialty foods.  The food is prepared in a production line, where an individual may only perform one task, such as measuring corn & oil into a popper.  The next individual would salt & bag.  The next individual would choose correct bag as per customer order & hand to teller.  The next individual would have taken order, taken money, made change & then hands order to client."
# question = "Responsible for servicing, cleaning, and supplying restrooms, performing routine maintenance activities, notifying management of need for repairs, cleaning snow or debris from sidewalk, and performing heavy cleaning duties such as cleaning floors, shampooing rugs, washing walls and glass, and removing rubbish."
question = "DUTIES include: apply caulk, sealants, or other agents to installed surfaces; apply grout between joints of bricks or tiles, using grouting trowels; arrange or store materials, machines, tools, or equipment; clean installation surfaces, equipment, tools, work sites, or storage areas, using water, chemical solutions, oxygen lances, or polishing machines; correct surface imperfections or fill chipped, cracked, or broken bricks or tiles, using fillers, adhesives, or grouting materials; cut materials to specified sizes for installation, using power saws or tile cutters; erect scaffolding or other installation structures; locate and supply materials to masons for installation; mix mortar, plaster, and grout, manually or using machines, according to standard formulas; modify material moving, mixing, grouting, grinding, polishing, or cleaning procedures, according to installation or material requirements; move or position materials such as marble slabs, assisting team members using cranes, hoists, or dollies; provide assistance in the preparation, installation, repair, or rebuilding of tile, brick, or stone surfaces; remove damaged tile, brick, or mortar, and clean or prepare surfaces, using pliers, hammers, chisels, drills, wire brushes, or metal wire anchors; remove excess grout or residue from tile or brick joints, using sponges or trowels; transport materials, tools, or machines to installation sites, manually or using conveyance equipment."
question_embedding = get_embeddings([question]).numpy()
question_embedding.shape

scores, samples = embeddings_dataset.get_nearest_examples(
    "embeddings", question_embedding, k=5
)

samples_df = pd.DataFrame.from_dict(samples)
samples_df["scores"] = scores
samples_df.sort_values("scores", ascending=False, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# MissingIndex                              Traceback (most recent call last)
# <ipython-input-27-1e6295dcf26e> in <cell line: 7>()
#       5 question_embedding.shape
#       6
# ----> 7 scores, samples = embeddings_dataset.get_nearest_examples(
#       8     "embeddings", question_embedding, k=5
#       9 )
#
# /usr/local/lib/python3.10/dist-packages/datasets/search.py in get_nearest_examples(self, index_name, query, k, **kwargs)
#     745                 - **examples** (`dict`): the retrieved examples
#     746         """
# --> 747         self._check_index_is_initialized(index_name)
#     748         scores, indices = self.search(index_name, query, k, **kwargs)
#     749         top_indices = [i for i in indices if i >= 0]
#
# /usr/local/lib/python3.10/dist-packages/datasets/search.py in _check_index_is_initialized(self, index_name)
#     425     def _check_index_is_initialized(self, index_name: str):
#     426         if not self.is_index_initialized(index_name):
# --> 427             raise MissingIndex(
#     428                 f"Index with index_name '{index_name}' not initialized yet. Please make sure that you call `add_faiss_index` or `add_elasticsearch_index` first."
#     429             )
#
# MissingIndex: Index with index_name 'embeddings' not initialized yet. Please make sure that you call `add_faiss_index` or `add_elasticsearch_index` first.

# %%
for _, row in samples_df.iterrows():
    print(f"SOC: {row.label}")
    print(f"SCORE: {row.scores}")
    print(f"TEXT: {row.text}")
    print("=" * 50)
    print()

# %%
import joblib

# Save the dataset along with the Faiss index
joblib.dump(embeddings_dataset, "embeddings_dataset.joblib")
# Out:
# ['embeddings_dataset.joblib']

# %%
loaded_dataset = joblib.load("embeddings_dataset.joblib")

question = "DUTIES include: apply caulk, sealants, or other agents to installed surfaces; apply grout between joints of bricks or tiles, using grouting trowels; arrange or store materials, machines, tools, or equipment; clean installation surfaces, equipment, tools, work sites, or storage areas, using water, chemical solutions, oxygen lances, or polishing machines; correct surface imperfections or fill chipped, cracked, or broken bricks or tiles, using fillers, adhesives, or grouting materials; cut materials to specified sizes for installation, using power saws or tile cutters; erect scaffolding or other installation structures; locate and supply materials to masons for installation; mix mortar, plaster, and grout, manually or using machines, according to standard formulas; modify material moving, mixing, grouting, grinding, polishing, or cleaning procedures, according to installation or material requirements; move or position materials such as marble slabs, assisting team members using cranes, hoists, or dollies; provide assistance in the preparation, installation, repair, or rebuilding of tile, brick, or stone surfaces; remove damaged tile, brick, or mortar, and clean or prepare surfaces, using pliers, hammers, chisels, drills, wire brushes, or metal wire anchors; remove excess grout or residue from tile or brick joints, using sponges or trowels; transport materials, tools, or machines to installation sites, manually or using conveyance equipment."
question_embedding = get_embeddings([question]).numpy()
question_embedding.shape

scores, samples = loaded_dataset.get_nearest_examples(
    "embeddings", question_embedding, k=5
)

samples_df = pd.DataFrame.from_dict(samples)
samples_df["scores"] = scores
samples_df.sort_values("scores", ascending=False, inplace=True)

for _, row in samples_df.iterrows():
    print(f"SOC: {row.label}")
    print(f"SCORE: {row.scores}")
    print(f"TEXT: {row.text}")
    print("=" * 50)
    print()
# Out:
# SOC: 47-3011.00
# SCORE: 14.699073791503906
# TEXT: Assist masons and finishers as needed. Loading and unloading materials. Gathering and removing litter. Provide assistance in the preparation, installation, repair, or rebuilding of tile, brick, or stone surfaces. Locate and supply materials to masons for installation, following drawings or numbered sequences. Arrange or store materials, machines, tools, or equipment. May use hand or power tools or equipment or vehicles to complete these tasks.
# ==================================================
#
# SOC: 47-2022.00
# SCORE: 14.39815616607666
# TEXT: Duties may include: Provide assistance in the preparation for installation or repair of bricks, tiles, or other stone surfaces. Move, position, and transport materials, tools, or machines to installation sites, manually using dollies, hoists, cranes, or conveyance equipment. Erect scaffolding. Lay out wall patterns or foundations, using straight edge, ruler, or staked lines. Use hand tools to shape, trim, face, and cut bricks, tiles, marble or other stone material and set vertical and horizontal alignment of structures. Remove wedges, damaged bricks, tiles, marble, stone, mortar, and clean or prepare surfaces. Correct surface imperfections, fill chipped, cracked, or broken bricks, tiles, marble or stone. Cut materials to specified sizes for installation, using power saws or tile cutters. Mix mortar, plaster, and grout, manually or using machines. Apply grout between joints using grouting trowels. Remove excess grout or residue from joints, using sponges or trowels & other related Stone Mason  activities as per SOC/OES 47-2022 (onetonline.org).
#
# Possible weekend/holiday work.
# ==================================================
#
# SOC: 47-3011.00
# SCORE: 12.734358787536621
# TEXT: Duties may include: Mix mortar, plaster, and grout, manually or using machines. Erect scaffolding or other installation structures. Provide assistance in the preparation, installation, repair, or rebuilding of tile, brick, or stone surfaces. Remove excess grout or residue from tile or brick joints, using sponges or trowels. Apply grout between joints of bricks or tiles, using grouting trowels. Remove damaged tile, brick, or mortar, and clean or prepare surfaces. Correct surface imperfections or fill chipped, cracked, or broken bricks or tiles & other related Helpers--Brickmasons activities as per SOC/OES 47-3011 (onetonline.org).
#
# Possible weekend/holiday work.
# ==================================================
#
# SOC: 47-3011.00
# SCORE: 11.971463203430176
# TEXT: Duties may include: Mix mortar, plaster, and grout, manually or using machines. Erect scaffolding or other installation structures. Provide assistance in the preparation, installation, repair, or rebuilding of tile, brick, or stone surfaces. Remove excess grout or residue from tile or brick joints, using sponges or trowels. Apply grout between joints of bricks or tiles, using grouting trowels. Remove damaged tile, brick, or mortar, and clean or prepare surfaces. Correct surface imperfections or fill chipped, cracked, or broken bricks or tiles & other related Helpers Brickmasons activities as per SOC/OES 47-3011 (onetonline.org).
#
# Possible weekend/holiday work.
# ==================================================
#
# SOC: 47-3011.00
# SCORE: 0.004544297233223915
# TEXT: DUTIES include: apply caulk, sealants, or other agents to installed surfaces; apply grout between joints of bricks or tiles, using grouting trowels; arrange or store materials, machines, tools, or equipment; clean installation surfaces, equipment, tools, work sites, or storage areas, using water, chemical solutions, oxygen lances, or polishing machines; correct surface imperfections or fill chipped, cracked, or broken bricks or tiles, using fillers, adhesives, or grouting materials; cut materials to specified sizes for installation, using power saws or tile cutters; erect scaffolding or other installation structures; locate and supply materials to masons for installation; mix mortar, plaster, and grout, manually or using machines, according to standard formulas; modify material moving, mixing, grouting, grinding, polishing, or cleaning procedures, according to installation or material requirements; move or position materials such as marble slabs, assisting team members using cranes, hoists, or dollies; provide assistance in the preparation, installation, repair, or rebuilding of tile, brick, or stone surfaces; remove damaged tile, brick, or mortar, and clean or prepare surfaces, using pliers, hammers, chisels, drills, wire brushes, or metal wire anchors; remove excess grout or residue from tile or brick joints, using sponges or trowels; transport materials, tools, or machines to installation sites, manually, or using conveyance equipment.
# ==================================================

# %%
df_train[0:5]
# Out:
# [{'text': 'Tasks include: Operate vehicles and powered equipment, such as mowers, tractors, twin-axle vehicles, snow blowers, chainsaws, electric clippers, sod cutters, and pruning saws. Mow or edge lawns. Shovel snow and salt walks, driveways, or parking lots. Care for established lawns by mulching, aerating, weeding, grubbing, removing thatch, or trimming or edging around flower beds, walks, or walls.  Use hand tools, such as shovels, rakes, pruning saws, hedge or brush trimmers, or axes. Prune or trim trees, shrubs, or hedges. Gather and remove litter. Maintain or repair tools, equipment, or structures, such as building, greenhouses, fences, or benches, using hand or power tools. Mix and spray fertilizers, herbicides, or insecticides onto grass, shrubs, or trees.',
#   'label': '37-3011.00'},
#  {'text': 'Prepare construction site where concrete will be poured. Assist in pouring of concrete for finishers to complete. Use hand and power tools and carry various construction materials. Dig and level earth and gravel. Clean up construction site.',
#   'label': '47-2061.00'},
#  {'text': 'Perform a variety of food preparation duties other than cooking. Prepare a variety of foods, such as meats, vegetables, or desserts, according to customers. Place food trays over food warmers for immediate service, or store them in refrigerated storage cabinets.',
#   'label': '35-2021.00'},
#  {'text': '***RFI Response***\n\xa0\n- Prep Station\n\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 \xa0 When they clock in they need to prep their station just like Soup, Sauce, Veg, Meat before the business open.\n\n- Cook\n\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 \xa0 Workers have to cook with a Chinese wok. We have our premade sauce in their station. We have a Chef assistant to prep all the ingredient and hand it to them, What they need to do is stir fry all veg, meat and sauce together and make sure that every ingredient is well done.\n\n- Fill ingredient\n\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 \xa0 After busy hours they need to clean up their station and fill all the sauce.\n\xa0\n-\xa0Prep Vegetable and Meat\n\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0They need to do it around afternoon after a 1 hour break. What they need to do is use Knife and Meat Slicer.\n\xa0\n- Cleaning\n\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 \xa0 Help to clean the kitchen just like Sweep, Mop, Wash station and wok. Keep all Meat and Veg in the refrigerator. (Cleaning job is not for one person but everybody need to help each other)\n\n\xa0***Original F.a.2***\n\nIn a day most of the job is on cook station  making an order.\nAfter rush time prep : Meat , Vegetable , Sauce , Curry.\nAfter business hours : Clean station , Check stock.\n\n\n',
#   'label': '35-2014.00'},
#  {'text': 'Greet, register and assign rooms to guests. Issue room keys. Make and confirm reservations. Collect payment. Answer questions, address complaints and report problems. Perform basic administrative duties associated with being a front desk clerk. Operating telephones in a polite and friendly manner following proper telephone etiquette, greeting members and guests, assisting with reservations and luggage, distributing information and schedules, and collecting and sorting the mail on a daily basis. May assist with breakfast preparation set up.  The Front Desk Clerk will also be responsible for making sure the rooms are properly cleaned and ready for check-in.',
#   'label': '43-4081.00'}]

# %%
df_train[657]
# Out:
# {'text': 'Perform variety of attending duties at traveling carnival.  Set up, tear-down, operate amusement rides, food concessions, game concessions and/or novelty concessions.\n\nThe OFLC ETA requested detail on specific portions of these job duties.  \n\nAmusement Rides set up & tear down:  Mobile amusement rides are trailer mounted.  A supervisor would position the trailer(s) at a specific location on the grounds, unhitch the power unit from the trailer, & move the power unit away from the ride.  All of the pieces of the ride would travel on the same trailer(s) & be located proximate to their position when the ride is in operation.   Work would be performed by individual workers as members of a team, with some tasks being performed individually & some collectively.  Restraints holding pieces of the ride while in transit would be released.  Ride platform (if any) would be lowered & leveled.  Track or railing (if any) would be positioned & connected.  Sweeps, supports, bars, pins would be positioned & connected.  Cars, Seats, Bench or Carriage (method of conveyance for this particular ride) where patron would stand or sit while on the ride would be positioned & connected.  Fencing, signage, ticket collection boxes & illumination would be positioned.  Teardown would simply be these duties being handled in the reverse order & items being stored & secured for transit to the next location.  May include moving/positioning, maintenance, repairs and refurbishment of equipment.\n\nFood Concessions set up & tear down:  Mobile food concessions are typically mounted in a trailer.  A supervisor would position the trailer(s) at a specific location on the grounds, unhitch the power unit from the trailer.  The awnings covering the windows during transit would be raised & secured.  Items such as trash cans, screens, tables that may be positioned outside of the trailer but carried inside of the trailer during transit would be manually moved from inside the trailer to outside.  Trailer would be cleaned, sanitized & stocked with supplies for the event.  Any counters, guidance railings, signage, decorations would be positioned outside of the trailer. Condiment dispensers, napkin dispensers & trash containers would be set up outside of the trailer. Typically the fair or event maintains the tables & chairs for patrons, but is some instances the worker may set up a limited number of chairs & tables for patron use.  Teardown would simply be these duties being handled in the reverse order & items being stored & secured for transit to the next location.\n\nGame Concessions:  Mobile game concessions are typically mounted in a trailer.  A supervisor would position the trailer(s) at a specific location on the grounds, unhitch the power unit from the trailer, & move the power unit away from the game concessions trailer.  The awning that is closed during transit would be opened.  Gaming items (air guns, water guns, darts, etc., as appropriate for the game) would be positioned.  Plush toys and/or game appropriate prizes would be positioned / displayed. Signage, illumination, seating (if any), railings (if any), fencing (if any) would be positioned.  Teardown would simply be these duties being handled in the reverse order & items being stored & secured for transit to the next location.\n\nTo clarify the portion of the job duties that includes operate mobile food concessions stand:   On a carnival midway, when there is a mobile food concessions, a stand is limited to selling only one or two specific items, such as cotton candy, popcorn, turkey legs, roasted corn, or other specialty foods.  The food is prepared in a production line, where an individual may only perform one task, such as measuring corn & oil into a popper.  The next individual would salt & bag.  The next individual would choose correct bag as per customer order & hand to teller.  The next individual would have taken order, taken money, made change & then hands order to client.',
#  'label': '35-3023.00'}

# %%
abc = pd.DataFrame(df_train)[0:2000]
abc[abc['label'] == '35-3023.00']
# Out:
#                                                    text       label
# 113   TAKE ORDERS AND ACCEPT PAYMENT FROM CUSTOMERS ...  35-3023.00
# 155   Duties include simple cooking and selling of f...  35-3023.00
# 171   Perform variety of attending duties at mobile ...  35-3023.00
# 263   Perform duties which combine both food prepara...  35-3023.00
# 408   Perform duties which combine both food prepara...  35-3023.00
# 448   Take orders and serve food over a counter. Acc...  35-3023.00
# 517   EMPLOYEES MAY BE ASSIGNED TO WORK IN VARIOUS A...  35-3023.00
# 535   Perform variety of attending duties at mobile ...  35-3023.00
# 647   Crew member for fast food restaurant. Tasks: m...  35-3023.00
# 657   Perform variety of attending duties at traveli...  35-3023.00
# 775   Providing guests with excellent service and qu...  35-3023.00
# 859   SERVE STORE CUSTOMERS BY PREPARING MEALS TO GO...  35-3023.00
# 861   GREET AND INTERACT WITH CUSTOMERS. ANSWER QUES...  35-3023.00
# 927   GREET AND INTERACT WITH CUSTOMERS. ANSWER QUES...  35-3023.00
# 936   Perform variety of attending duties at traveli...  35-3023.00
# 949   Perform variety of attending duties at traveli...  35-3023.00
# 1409  Perform a variety of attending duties at amuse...  35-3023.00
# 1450  CLEAN, WASH, ERECT, AND TAKE DOWN EQUIPMENT (F...  35-3023.00
# 1682  Providing guests with excellent service in all...  35-3023.00
# 1720  Perform variety of attending duties at mobile ...  35-3023.00
# 1741  Collect tickets; assist patrons; erect, take d...  35-3023.00
# 1955  Duties include simple cooking and selling food...  35-3023.00

# %%
df_test[0:5]
# Out:
# [{'text': 'Ability to smooth & finish surfaces of poured concrete, such as floors, walks, sidewalks, or curbs using a variety of hand & power tools. Align forms for sidewalks, curbs or gutters. May perform other duties and tasks per SOC Code 47-2051.00.',
#   'label': '47-2051.00'},
#  {'text': "Attends to the overall care of thoroughbred race horses including feeding, watering,\nmaintenance of stalls and tack, cleaning, brushing, trimming of horses, disinfecting stalls and\nbedding, administration of meds as directed, inspection of horses' physical condition. Will lift\nlegs and clean horses' feet and apply liniments and bandages to legs as required. Will care for\n1-5 horses at a time, including hot walking and tacking up. Work day is split: 5am11am,3pm-5pm. Days off rotates.",
#   'label': '39-2021.00'},
#  {'text': 'Responsible for servicing, cleaning, and supplying restrooms, performing routine maintenance activities, notifying management of need for repairs, cleaning snow or debris from sidewalk, and performing heavy cleaning duties such as cleaning floors, shampooing rugs, washing walls and glass, and removing rubbish.',
#   'label': '37-2011.00'},
#  {'text': 'DUTIES include: apply caulk, sealants, or other agents to installed surfaces; apply grout between joints of bricks or tiles, using grouting trowels; arrange or store materials, machines, tools, or equipment; clean installation surfaces, equipment, tools, work sites, or storage areas, using water, chemical solutions, oxygen lances, or polishing machines; correct surface imperfections or fill chipped, cracked, or broken bricks or tiles, using fillers, adhesives, or grouting materials; cut materials to specified sizes for installation, using power saws or tile cutters; erect scaffolding or other installation structures; locate and supply materials to masons for installation; mix mortar, plaster, and grout, manually or using machines, according to standard formulas; modify material moving, mixing, grouting, grinding, polishing, or cleaning procedures, according to installation or material requirements; move or position materials such as marble slabs, assisting team members using cranes, hoists, or dollies; provide assistance in the preparation, installation, repair, or rebuilding of tile, brick, or stone surfaces; remove damaged tile, brick, or mortar, and clean or prepare surfaces, using pliers, hammers, chisels, drills, wire brushes, or metal wire anchors; remove excess grout or residue from tile or brick joints, using sponges or trowels; transport materials, tools, or machines to installation sites, manually or using conveyance equipment.',
#   'label': '47-3011.00'},
#  {'text': 'Duties may include: Care for established lawns by mowing, trimming, edging, mulching, aerating, weeding, watering, removing thatch, litter & debris. Prune or trim trees, shrubs, or hedges, using shears & pruners to improve growth. Spray or spread fertilizer onto trees, shrubs & lawns. Maintain walks, driveways, parking lots & other related Landscape Laborer activities as per SOC/OES 37-3011 (onetonline.org).\n\nPossible weekend/holiday work.',
#   'label': '37-3011.00'}]
